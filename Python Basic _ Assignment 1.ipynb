# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
#
# Ans:
#
# * #mathematical operators
# 'hello' #mathematical operators
# -87.8 #value
# - #mathematical operators
# / #mathematical operators
# + #mathematical operators
# 6 #value

# %% [raw]
# 2. What is the difference between string and variable?
#
# Ans:
#
# String is a type of data which generally contains text. It is enclosed in "" or ''. It can contai numbers but mathematical operations can not be done on it.
#
# Variable is an object which stores any type of data (strings, integer, float, Lists, etc) in it.

# %% [raw]
# 3. Describe three different data types.
#
# Ans:
#
# string : generally contains text. It is enclosed in "" or ''. It can contai numbers but mathematical operations can not be done on it.
#
# int : includes all integer values
#
# float : includes all real numbers. It has decimal point in it.

# %% [raw]
# 4. What is an expression made up of? What do all expressions do?
#
# Ans:
#
# Expressions are made up of mathematical operatores (+,-, etc) and data (of any type- int, strings, etc).
# Expressions perform operations on the data in them and return the output.

# %% [raw]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?
#
# Ans:
#
# Expressions return the value.
# Statements dont return the value

# %% [raw]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Ans:
#
# bacon has value of 22.

# %% [raw]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Ans:
#
# 'spamspamspam'
# 'spamspamspam'

# %% [raw]
# Why is eggs a valid variable name while 100 is invalid?
#
# Ans:
#
# In python, variable name cant start with a number.

# %% [raw]
# 9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?
#
# Ans:
#
# int()
# float()
# str()

# %% [raw]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Ans:
#
# Operators dont work between strings and int data types. Hence, 99 needs to be coverted into a string.
# 'I have eaten ' + str(99) + ' burritos.'
